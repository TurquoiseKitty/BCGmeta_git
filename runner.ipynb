# %%
from run_experiment import runner

runner("configs/BCG_NN.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.999, max:    2.731, cur:    1.003)
# valid loss
# 	valid loss       	 (min:    0.996, max:    2.492, cur:    0.998)

# %%
from run_experiment import runner

runner("configs/BCG_RES_NN.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.988, max:    2.798, cur:    0.989)
# valid loss
# 	valid loss       	 (min:    0.999, max:    2.536, cur:    1.001)

# %%
from test import KL_loss_check

KL_loss_check("configs/BCG_NN.yaml", "BCG_NN")
# Out:
# Test KL loss:  {'KL_loss': tensor(1.0628, device='cuda:0', grad_fn=<DivBackward1>)}
# Silly prediction KL loss:  {'KL_loss': tensor(3.2544, device='cuda:0')}

# %%
from test import KL_loss_check

KL_loss_check("configs/BCG_NN_warm.yaml", "BCG_NN_warm")
# Out:
# Test KL loss:  {'KL_loss': tensor(1.0604, device='cuda:0', grad_fn=<DivBackward1>)}
# Silly prediction KL loss:  {'KL_loss': tensor(3.2449, device='cuda:0')}

# %%
from test import KL_loss_check

KL_loss_check("configs/BCG_RES_NN.yaml", "BCG_RES_NN")
# Out:
# Test KL loss:  {'KL_loss': tensor(1.0606, device='cuda:0', grad_fn=<DivBackward1>)}
# Silly prediction KL loss:  {'KL_loss': tensor(3.2753, device='cuda:0')}

# %%
from test import KL_loss_check

KL_loss_check("configs/BCG_RES_NN_warm.yaml", "BCG_RES_NN_warm")
# Out:
# Test KL loss:  {'KL_loss': tensor(1.0583, device='cuda:0', grad_fn=<DivBackward1>)}
# Silly prediction KL loss:  {'KL_loss': tensor(3.2532, device='cuda:0')}
