# %%
from run_experiment import runner

runner("configs/H4.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.819, max:    1.890, cur:    0.832)
# valid loss
# 	valid loss       	 (min:    0.570, max:    1.805, cur:    0.604)

# %%
from test import KL_loss_check

KL_loss_check("configs/H4.yaml", "H4")
# Out:
# Test KL loss:  {'KL_loss': tensor(0.6780, device='cuda:0', grad_fn=<DivBackward1>)}
# Silly prediction KL loss:  {'KL_loss': tensor(2.1205, device='cuda:0')}

# %%
from run_experiment import runner

runner("configs/H2_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.758, max:    1.641, cur:    0.758)
# valid loss
# 	valid loss       	 (min:    0.754, max:    1.510, cur:    0.754)

# %%
from run_experiment import runner

runner("configs/H4_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.780, max:    1.645, cur:    0.780)
# valid loss
# 	valid loss       	 (min:    0.775, max:    1.538, cur:    0.775)

# %%
from run_experiment import runner

runner("configs/H5_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.728, max:    1.653, cur:    0.728)
# valid loss
# 	valid loss       	 (min:    0.725, max:    1.519, cur:    0.725)

# %%
from run_experiment import runner

runner("configs/H2_warm.yaml", model_path = "logs/H2_tune/H2_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.608, max:    0.659, cur:    0.623)
# valid loss
# 	valid loss       	 (min:    0.663, max:    0.706, cur:    0.666)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3032/2105500512.py in <module>
#       1 from run_experiment import runner
#       2
# ----> 3 runner("configs/H2_warm.yaml", model_path = "logs/H2_tune/H2_tune_last.pth")
#
# D:\CODING\NEW_Assortment_NN\HOTEL_finetune\run_experiment.py in runner(yaml_path, datapath_overwrite, demo, model_path)
#      58     )
#      59
# ---> 60     EXP.run(echo=False)
#      61
#      62
#
# D:\CODING\NEW_Assortment_NN\HOTEL_finetune\train.py in run(self, echo)
#     173             for step, (IN_bat, SAMP_bat, *PROB_bat) in enumerate(self.T_loader):
#     174
# ...

# %%
from run_experiment import runner

runner("configs/H4_warm.yaml", model_path = "logs/H4_tune/H4_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.821, max:    0.870, cur:    0.834)
# valid loss
# 	valid loss       	 (min:    0.577, max:    1.671, cur:    0.603)

# %%
from run_experiment import runner

runner("configs/H5_warm.yaml", model_path = "logs/H5_tune/H5_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.787, max:    0.824, cur:    0.793)
# valid loss
# 	valid loss       	 (min:    0.840, max:    0.866, cur:    0.850)
