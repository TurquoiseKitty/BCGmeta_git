# %%
from run_experiment import runner

runner("configs/Res2_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.758, max:    1.641, cur:    0.758)
# valid loss
# 	valid loss       	 (min:    0.754, max:    1.511, cur:    0.754)

# %%
from run_experiment import runner

runner("configs/Res4_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.780, max:    1.645, cur:    0.780)
# valid loss
# 	valid loss       	 (min:    0.775, max:    1.539, cur:    0.775)

# %%
from run_experiment import runner

runner("configs/Res5_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.728, max:    1.653, cur:    0.728)
# valid loss
# 	valid loss       	 (min:    0.724, max:    1.519, cur:    0.724)

# %%
from run_experiment import runner

runner("configs/Res2_warm.yaml", model_path = "logs/Res2_tune/Res2_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.609, max:    0.659, cur:    0.623)
# valid loss
# 	valid loss       	 (min:    0.663, max:    0.705, cur:    0.666)

# %%
from run_experiment import runner

runner("configs/Res4_warm.yaml", model_path = "logs/Res4_tune/Res4_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.838, max:    0.870, cur:    0.854)
# valid loss
# 	valid loss       	 (min:    0.577, max:    0.610, cur:    0.596)

# %%
from run_experiment import runner

runner("configs/Res5_warm.yaml", model_path = "logs/Res5_tune/Res5_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.787, max:    0.824, cur:    0.793)
# valid loss
# 	valid loss       	 (min:    0.840, max:    0.879, cur:    0.850)
