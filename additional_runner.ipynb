# %%
from run_experiment import runner

runner("configs/BCG_NN_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.876, max:    2.036, cur:    0.876)
# valid loss
# 	valid loss       	 (min:    0.867, max:    1.841, cur:    0.867)

# %%
from run_experiment import runner

runner("configs/BCG_RES_NN_tune.yaml")
# Out:
# train loss
# 	train loss       	 (min:    0.870, max:    2.002, cur:    0.870)
# valid loss
# 	valid loss       	 (min:    0.864, max:    1.748, cur:    0.865)

# %%
from run_experiment import runner

runner("configs/BCG_NN_warm.yaml", model_path = "logs/BCG_NN_tune/BCG_NN_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.994, max:    1.158, cur:    0.995)
# valid loss
# 	valid loss       	 (min:    0.995, max:    1.096, cur:    0.999)

# %%
from run_experiment import runner

runner("configs/BCG_RES_NN_warm.yaml", model_path = "logs/BCG_RES_NN_tune/BCG_RES_NN_tune_last.pth")
# Out:
# train loss
# 	train loss       	 (min:    0.982, max:    1.120, cur:    0.984)
# valid loss
# 	valid loss       	 (min:    0.995, max:    1.040, cur:    0.996)
